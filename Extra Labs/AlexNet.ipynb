# %% [markdown]
# Extra Lab Work based On FashionMnist

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten,Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import to_categorical

# %%
#Load fashion_mnist dataset
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()

# %%
#To Correctly input the data into the model
print(x_train.shape) 
print(y_train.shape)  
print(x_test.shape)   
print(y_test.shape)
# Out:
# (60000, 28, 28)
# (60000,)
# (10000, 28, 28)
# (10000,)

# %%
#NOrmalize the images to the range [0, 1]
x_train =  x_train / 255.0
x_test = x_test / 255.0

# %%
#Convert class vectors to binary class matrices (one-hot encoding)
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# %%
#Define ALexNet model in Keras
input_shape =(28,28,1)
num_classes = 10
fashionmnist = models.Sequential()

#Layer 1 : Conv Layer
fashionmnist.add(Conv2D(96,(11,11),strides=4,padding='same',input_shape=input_shape))
fashionmnist.add(layers.BatchNormalization())#Should be positioned Before the Activation Function
fashionmnist.add(layers.Activation('relu'))
fashionmnist.add(MaxPooling2D(pool_size=(2,2),strides=(1,1)))

#Layer 2: Conv Layer
fashionmnist.add(Conv2D(256,(5,5),padding='same'))
fashionmnist.add(layers.BatchNormalization())
fashionmnist.add(layers.Activation('relu'))
fashionmnist.add(MaxPooling2D(pool_size=(2,2),strides=(1,1)))


#Fattening Layer
fashionmnist.add(Flatten())


#Layer 8 : Output Layer
fashionmnist.add(Dense(num_classes))
fashionmnist.add(layers.Activation('softmax'))
#Final Layer
# Out:
# c:\Users\user\Desktop\MCA AI DS 2027\S2\Deep Learning\Lab\tfenv\lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
#compile the model
fashionmnist.compile(optimizer=Adam(learning_rate=0.01),loss='categorical_crossentropy',metrics=['accuracy'])

# %%
fashionmnist.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 7, 7, 96)       │        11,712 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 7, 7, 96)       │           384 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 7, 7, 96)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 6, 6, 96)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...

# %%
#--model architecture
tf.keras.utils.plot_model(fashionmnist,show_layer_names=True,show_shapes=True,show_dtype=False)
# Out:
# You must install graphviz (see instructions at https://graphviz.gitlab.io/download/) for `plot_model` to work.

# %%
pip install pydot

# %%
#Create data Augmentation generator
datagen = ImageDataGenerator(
    width_shift_range = 0.1 , #randomly shift images Horizontally
    height_shift_range = 0.1, #Randomly Shift images Vertically
    horizontal_flip = True #randomly flip images Horizontally
)

# %%
datagen.fit(x_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 datagen.fit(x_train)
#
# File c:\Users\user\Desktop\MCA AI DS 2027\S2\Deep Learning\Lab\tfenv\lib\site-packages\keras\src\legacy\preprocessing\image.py:1488, in ImageDataGenerator.fit(self, x, augment, rounds, seed)
#    1486 x = np.asarray(x, dtype=self.dtype)
#    1487 if x.ndim != 4:
# -> 1488     raise ValueError(
#    1489         "Input to `.fit()` should have rank 4. Got array with shape: "
#    1490         + str(x.shape)
#    1491     )
#    1492 if x.shape[self.channel_axis] not in {1, 3, 4}:
#    1493     warnings.warn(
#    1494         "Expected input to be images (as Numpy array) "
#    1495         f'following the data format convention "{self.data_format}'
#    (...)
#    1499         f" shape {x.shape} ({x.shape[self.channel_axis]} channels)."
#    1500     )
#
# ...

# %%
#Train Model 
history = fashionmnist.fit(datagen.flow(x_train,y_train,batch_size=512),
                            epochs = 2,
                            validation_data = (x_test,y_test),
                            verbose = 1)

# %%
#Evaluate The Model
test_loss,test_acc = fashionmnist.evaluate(x_test,y_test,verbose=2)
print(f'Test Accuracy:{test_acc}')

# %%
#plot Training and validation accuracy and loss
import matplotlib.pyplot as plt
plt.figure(figsize=(14,5))

plt.subplot(1,2,1)
plt.plot(history.history['accuracy'],label='Training Accuracy')
plt.plot(history.history['val_accuracy'],label='validation Accuracy')
plt.legend(loc='lower right')
plt.title("Training and Validation Accuracy")

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')

plt.savefig('./Alexnet.png')
plt.show()
